# %% [markdown]
# # ML_NLP_Final Project : Abstract Distinguisher

# %% [markdown]
# # POUYA AHADI 400123014 pa@ieee.org

# %% [markdown]
# # First Phase: Collecting raw data

# %%
import os
import pandas as pd
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt
import regex as re

# %%
df_add = f'//Users//pouyaahadi//Desktop//فایل های ارشد//ML - AUT//NLP//Final_Dataset//Final_English_Dataset.csv'

# %%
os.listdir()
# Out:
# ['Dataset_given.csv',
#  'Dataset_Example (1).xlsx',
#  '.DS_Store',
#  '1810.04805.pdf',
#  'Articles',
#  'Untitled 2.pages',
#  'Final_Dataset',
#  'تقویم آموزشی دانشگاه صنعتی امیرکبیر.pdf',
#  'Dataset_Pouya_Ahadi_400123014.xlsx',
#  '.ipynb_checkpoints',
#  'ML(1401.03.09).pdf',
#  'پروژه نهایی درس یادگیری ماشین.pdf',
#  'Dataset.csv',
#  'NLP_Pouya.ipynb']

# %%
df = pd.read_csv('Dataset.csv', encoding="latin1")

# %%
#df.head()
df
# Out:
#                                                    text  Relevant
# 0     Twitter's shares fell by more than 25pc in Oct...         1
# 1     A company with no revenues and barely any staf...         1
# 2     YouTube has been around forever, in digital te...         1
# 3     The New York offices of stockbrokers JP Morgan...         1
# 4     Facebook executives have been cautioning inves...         1
# ...                                                 ...       ...
# 2218  Many concepts have been proposed for meta lear...         0
# 2219  Many online communities present user-contribut...         0
# 2220  Logistic-normal topic models can effectively d...         0
# 2221  Principal geodesic analysis (PGA) is a general...         0
# 2222  We formulate the problem of optimizing the sam...         0
#
# [2223 rows x 2 columns]

# %%
df['text']
# Out:
# 0       Twitter's shares fell by more than 25pc in Oct...
# 1       A company with no revenues and barely any staf...
# 2       YouTube has been around forever, in digital te...
# 3       The New York offices of stockbrokers JP Morgan...
# 4       Facebook executives have been cautioning inves...
#                               ...
# 2218    Many concepts have been proposed for meta lear...
# 2219    Many online communities present user-contribut...
# 2220    Logistic-normal topic models can effectively d...
# 2221    Principal geodesic analysis (PGA) is a general...
# 2222    We formulate the problem of optimizing the sam...
# Name: text, Length: 2223, dtype: object

# %%
df['Relevant']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2218    0
# 2219    0
# 2220    0
# 2221    0
# 2222    0
# Name: Relevant, Length: 2223, dtype: int64

# %%
a =[]
for i in range(len(df.Relevant)):
    
    if df.Relevant[i] == 0:
           a.append(i)
            
#print(a)

b =[]
for i in range(len(df.Relevant)):
    
    if df.Relevant[i] == 1:
           b.append(i)

# %%
print('Total number of Data = ', len(df))

print('Total number of Social media relevancy = ', len(b))

print('Total number of Non-social media relevancy = ', len(a))

print('Total number of nulls in Relevant = ', len(df['Relevant'])-(len(b)+len(a)))
# Out:
# Total number of Data =  2223
# Total number of Social media relevancy =  1482
# Total number of Non-social media relevancy =  741
# Total number of nulls in Relevant =  0

# %%
df.isnull().sum()
# Out:
# text        0
# Relevant    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2223 entries, 0 to 2222
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      2223 non-null   object
#  1   Relevant  2223 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 34.9+ KB

# %%
dfn = df[df['text'].notnull()]

# %%
dfn
# Out:
#                                                    text  Relevant
# 0     Twitter's shares fell by more than 25pc in Oct...         1
# 1     A company with no revenues and barely any staf...         1
# 2     YouTube has been around forever, in digital te...         1
# 3     The New York offices of stockbrokers JP Morgan...         1
# 4     Facebook executives have been cautioning inves...         1
# ...                                                 ...       ...
# 2218  Many concepts have been proposed for meta lear...         0
# 2219  Many online communities present user-contribut...         0
# 2220  Logistic-normal topic models can effectively d...         0
# 2221  Principal geodesic analysis (PGA) is a general...         0
# 2222  We formulate the problem of optimizing the sam...         0
#
# [2223 rows x 2 columns]

# %%
dfn.text.sample(10,random_state=1)
# Out:
# 1502    FULL TEXT\n\nJust two weeks after admitting it...
# 808     Three people were injured by gunfire, one of t...
# 1262    ABSTRACT\n\nDan Gallagher Heard on the Street ...
# 1498    Google's decision-making process over which Yo...
# 111     ABSTRACT\n\nWhile its peers rush toward public...
# 1250    Facebook on Tuesday for the first time release...
# 918     Twitter may be about to end its three-month se...
# 1579    Click to view full-text\n\nhttps://www.nbcnews...
# 1938    "There's good creepy and there's bad creepy. A...
# 415     A NEW Facebook dating service has been put on ...
# Name: text, dtype: object

# %%
text_dfn = dfn['text']
text_dfn = text_dfn.to_frame()
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text
# 1502  FULL TEXT\n\nJust two weeks after admitting it...
# 808   Three people were injured by gunfire, one of t...
# 1262  ABSTRACT\n\nDan Gallagher Heard on the Street ...
# 1498  Google's decision-making process over which Yo...
# 111   ABSTRACT\n\nWhile its peers rush toward public...
# 1250  Facebook on Tuesday for the first time release...
# 918   Twitter may be about to end its three-month se...
# 1579  Click to view full-text\n\nhttps://www.nbcnews...
# 1938  "There's good creepy and there's bad creepy. A...
# 415   A NEW Facebook dating service has been put on ...

# %%
import nltk
from nltk.tokenize import word_tokenize
import contractions

# %%
text_dfn['text'] = text_dfn['text'].apply(lambda x: [contractions.fix(word) for word in x.split()])
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text
# 1502  [FULL, TEXT, Just, two, weeks, after, admittin...
# 808   [Three, people, were, injured, by, gunfire,, o...
# 1262  [ABSTRACT, Dan, Gallagher, Heard, on, the, Str...
# 1498  [Google's, decision-making, process, over, whi...
# 111   [ABSTRACT, While, its, peers, rush, toward, pu...
# 1250  [Facebook, on, Tuesday, for, the, first, time,...
# 918   [Twitter, may, be, about, to, end, its, three-...
# 1579  [Click, to, view, full-text, https://www.nbcne...
# 1938  ["There is, good, creepy, and, there is, bad, ...
# 415   [A, NEW, Facebook, dating, service, has, been,...

# %%
text_dfn['text'] = [' '.join(map(str,l)) for l in text_dfn['text']]
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text
# 1502  FULL TEXT Just two weeks after admitting it st...
# 808   Three people were injured by gunfire, one of t...
# 1262  ABSTRACT Dan Gallagher Heard on the Street art...
# 1498  Google's decision-making process over which Yo...
# 111   ABSTRACT While its peers rush toward public of...
# 1250  Facebook on Tuesday for the first time release...
# 918   Twitter may be about to end its three-month se...
# 1579  Click to view full-text https://www.nbcnews.co...
# 1938  "There is good creepy and there is bad creepy....
# 415   A NEW Facebook dating service has been put on ...

# %%
import regex as re

# %%
text_dfn['text'] = text_dfn['text'].str.lower()
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text
# 1502  full text just two weeks after admitting it st...
# 808   three people were injured by gunfire, one of t...
# 1262  abstract dan gallagher heard on the street art...
# 1498  google's decision-making process over which yo...
# 111   abstract while its peers rush toward public of...
# 1250  facebook on tuesday for the first time release...
# 918   twitter may be about to end its three-month se...
# 1579  click to view full-text https://www.nbcnews.co...
# 1938  "there is good creepy and there is bad creepy....
# 415   a new facebook dating service has been put on ...

# %%
text_dfn['text'] = text_dfn['text'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '',x))
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text
# 1502  full text just two weeks after admitting it st...
# 808   three people were injured by gunfire one of th...
# 1262  abstract dan gallagher heard on the street art...
# 1498  google's decisionmaking process over which you...
# 111   abstract while its peers rush toward public of...
# 1250  facebook on tuesday for the first time release...
# 918   twitter may be about to end its threemonth sea...
# 1579  click to view fulltext httpswwwnbcnewscomtecht...
# 1938  there is good creepy and there is bad creepy a...
# 415   a new facebook dating service has been put on ...

# %%
text_dfn['text'][0]
# Out:
# "twitter's shares fell by more than 25pc in october from highs of 55 the company has failed to dispel the age old concerns about technology float valuations and here are my five reasons why i would not invest in the 140 character microblogging site 1 no profits there are still no profits here and without a solid track record of posttax profits and without that investors' are buying on the belief of what the future will bring the dotcom boom of a decade ago was an example of extreme investor confidence when some companies' valuations were based on the number of clicks their websites got and had little or no relation to their profits or revenue twitter's results showed revenue in the third quarter more than doubling to 3613m when compared to the same period last year but losses almost tripled to 1755m at the same time that brings losses in the first nine months of the year to 4525m on revenue of 9239m one of the main reasons for those losses is that as twitter expanded it paid staff and customers with the promise of shares now the value of those shares has soared post flotation and they are impacting the company's profits as they are paid out twitter said the cost of stock options in the year ahead could reach 640m and that excludes any future acquisitions funded by issuing new shares issuing stock options will weigh on twitter's reported profits for the next three years 2 slowing growth investors buying twitter shares expect that the company will make losses for some years the idea is that the company will grow rapidly and that will require investment the hope is that once the company matures it can then start generating revenue from those users there are worrying signs at twitter which reported 284m monthly active users at the end of september up 13m on the previous three months and a rise of 23pc from the same period last year however just 3m of the 13m new users who joined twitter during the threemonth period were from the us raising fears that the social network could be reaching saturation point in the american market where twitter has been operating the longest the company also raised fears that it relies on big events to drive growth as it said users had slowed month on month because there was nothing to compare to the indian elections investors can stomach losses if they can see signs of tangible long term growth and after tax profits twitter is worrying by growth slowing and losses rising sharply 3 risk from competition investing in social media platforms is very high risk due to the low barriers to entry all the spending on technology can very quickly be made worthless by a new social media platform facebook was started in a college dormroom and twitter was started in 2006 social media platforms are a fickle fast moving landscape facebook is showing signs of generating stable revenues from its user base but for every success there are failures bebo the social network was once valued at 850m by aol but was recently sold for 1m and myspace at one time the most biggest social network in the world bought by rupert murdoch's newscorp for 580m was later sold for just 35m 4 balance sheet twitter is sitting on a cash mountain as the company reported 36bn in cash and short term investments that gives shareholder's funds of 352bn or with 615m shares in issue about 572 per share investors are currently paying seven times the book value for the shares and that looks too risky given the numbers 5 tech bubble shares in twitter remain a high risk prospect investors buying the shares are exposing themselves to capital losses the price at around 40 today may be above where shares floated at 26 but overseas investors only really got the opportunity to buy in at around 40 on the first days trading and we are now back at those levels twitter shares are trading on 425 times forecast earnings to the end of december and 119 times next year's forecast earnings the number one rule in investment is the preservation of capital and there is no h ...

# %%
df['text'][0]
# Out:
# "Twitter's shares fell by more than 25pc in October from highs of $55. The company has failed to dispel the age old concerns about technology float valuations.\n\nAnd here are my five reasons why I wouldn't invest in the 140 character micro-blogging site.\n\n1 No profits\n\nThere are still no profits here and without a solid track record of post-tax profits and without that investors' are buying on the belief of what the future will bring. The dotcom boom of a decade ago was an example of extreme investor confidence when some companies' valuations were based on the number of clicks their websites got, and had little or no relation to their profits or revenue.\n\nTwitter's results showed revenue in the third quarter more than doubling to $361.3m when compared to the same period last year, but losses almost tripled to $175.5m at the same time. That brings losses in the first nine months of the year to $452.5m, on revenue of $923.9m.\n\nOne of the main reasons for those losses is that as twitter expanded it paid staff and customers with the promise of shares, now the value of those shares has soared post flotation and they are impacting the company's profits as they are paid out.\n\nTwitter said the cost of stock options in the year ahead could reach $640m, and that excludes any future acquisitions funded by issuing new shares. Issuing stock options will weigh on Twitter's reported profits for the next three years.\n\n2 Slowing Growth\n\nInvestors buying Twitter shares expect that the company will make losses for some years. The idea is that the company will grow rapidly and that will require investment. The hope is that once the company matures it can then start generating revenue from those users.\n\nThere are worrying signs at Twitter, which reported 284m monthly active users at the end of September, up 13m on the previous three months and a rise of 23pc from the same period last year.\n\nHowever, just 3m of the 13m new users who joined Twitter during the three-month period were from the US, raising fears that the social network could be reaching saturation point in the American market, where Twitter has been operating the longest.\n\nThe company also raised fears that it relies on big events to drive growth as it said users had slowed month on month because there was nothing to compare to the Indian elections.\n\nInvestors can stomach losses if they can see signs of tangible long term growth and after tax profits. Twitter is worrying by growth slowing and losses rising sharply.\n\n3 Risk from competition\n\nInvesting in social media platforms is very high risk due to the low barriers to entry. All the spending on technology can very quickly be made worthless by a new social media platform. Facebook was started in a college dormroom, and Twitter was started in 2006.\n\nSocial media platforms are a fickle fast moving landscape. Facebook is showing signs of generating stable revenues from its user base, but for every success there are failures. Bebo the social network was once valued at $850m by AOL, but was recently sold for $1m, and Myspace at one time the most biggest social network in the world bought by Rupert Murdoch's Newscorp for $580m, was later sold for just $35m.\n\n4 Balance Sheet\n\nTwitter is sitting on a cash mountain as the company reported $3.6bn in cash and short term investments, that gives shareholder's funds of $3.52bn, or with 615m shares in issue about $5.72 per share.\n\nInvestors are currently paying seven times the book value for the shares and that looks too risky given the numbers.\n\n5 Tech bubble\n\nShares in Twitter remain a high risk prospect. Investors buying the shares are exposing themselves to capital losses. The price at around $40 today may be above where shares floated at $26, but overseas investors only really got the opportunity to buy in at around $40 on the first days trading and we are now back at those levels.\n\nTwitter shares are trading on 425 times forecast earnings to the end of  ...

# %%
text_dfn['tokenized_text'] = text_dfn['text'].apply(word_tokenize)
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text  \
# 1502  full text just two weeks after admitting it st...
# 808   three people were injured by gunfire one of th...
# 1262  abstract dan gallagher heard on the street art...
# 1498  google's decisionmaking process over which you...
# 111   abstract while its peers rush toward public of...
# 1250  facebook on tuesday for the first time release...
# 918   twitter may be about to end its threemonth sea...
# 1579  click to view fulltext httpswwwnbcnewscomtecht...
# 1938  there is good creepy and there is bad creepy a...
# 415   a new facebook dating service has been put on ...
#
#                                          tokenized_text
# 1502  [full, text, just, two, weeks, after, admittin...
# 808   [three, people, were, injured, by, gunfire, on...
# 1262  [abstract, dan, gallagher, heard, on, the, str...
# 1498  [google, 's, decisionmaking, process, over, wh...
# 111   [abstract, while, its, peers, rush, toward, pu...
# 1250  [facebook, on, tuesday, for, the, first, time,...
# 918   [twitter, may, be, about, to, end, its, threem...
# 1579  [click, to, view, fulltext, httpswwwnbcnewscom...
# 1938  [there, is, good, creepy, and, there, is, bad,...
# 415   [a, new, facebook, dating, service, has, been,...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pouyaahadi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from collections import defaultdict
def plot_stop_words_frequency(input):
    
    stop = set(stopwords.words('english'))
    new = input.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]
    dic = defaultdict(int) 
    for word in corpus:
        if word in stop:
            dic[word]+=1
            
    top = sorted(dic.items(), key=lambda x:x[1],reverse=True)[:20]
    x,y = zip(*top)
    plt.figure(figsize = (10,10))
    plt.bar(x,y)

# %%
plot_stop_words_frequency(text_dfn['text'])

# %% [raw]
# from nltk.probability import FreqDist
# from nltk.util import ngrams
#
# def wordcloud(text,stopwords,ngram=1):
#     # text: if ngram>1, text should be a dictionary
#     wordcloud = WordCloud(width=1400,
#                           height=800,
#                           background_color='black',
#                           stopwords=stop)
#     if ngram ==1:
#        wordc = wordcloud.generate(' '.join(text))
#     else:
#        wordc = wordcloud.generate_from_frequencies(text)
#     plt.figure(figsize=(20,10), facecolor='k')
#     plt.imshow(wordcloud)
#     plt.axis('off')
#     plt.tight_layout(pad=0)
# stop = set(stopwords.words('english'))
# wordcloud(text_dfn['text']==1,stop)

# %%
import seaborn as sns
from collections import Counter

# %%
def plot_Non_stop_words_frequency(input):
    
    stop = set(stopwords.words('english'))
    new = input.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]
    counter = Counter(corpus)
    most = counter.most_common()
    x,y=[],[]
    
    for word,count in most[:80]:
        if word not in stop:
            x.append(word)
            y.append(count)
            
    plt.figure(figsize = (20,10))
    sns.barplot(x=y,y=x)
    #plt.bar(x,y)

# %%
plot_Non_stop_words_frequency(text_dfn['text'])

# %% [raw]
# def wordcloud(text,stopwords,ngram=1):
#     # text: if ngram>1, text should be a dictionary
#     wordcloud = WordCloud(width=1400,
#                           height=800,
#                           background_color='black',
#                           stopwords=stop)
#     if ngram ==1:
#        wordc = wordcloud.generate(' '.join(text))
#     else:
#        wordc = wordcloud.generate_from_frequencies(text)    plt.figure(figsize=(20,10), facecolor='k')
#     plt.imshow(wordcloud)
#     plt.axis('off')
#     plt.tight_layout(pad=0)
# wordcloud(train_raw.question_text[train_raw['target']==1],stop)

# %% [markdown]
# # Removing the stop words

# %%
text_dfn['tokenized_text'] = text_dfn['tokenized_text'].apply(lambda x: [word for word in x if word not in stop_words])
text_dfn['tokenized_text_join'] = [' '.join(map(str,l)) for l in text_dfn['tokenized_text']]

# %%
text_dfn.sample(10,random_state=1)
# Out:
#                                                    text  \
# 1502  full text just two weeks after admitting it st...
# 808   three people were injured by gunfire one of th...
# 1262  abstract dan gallagher heard on the street art...
# 1498  google's decisionmaking process over which you...
# 111   abstract while its peers rush toward public of...
# 1250  facebook on tuesday for the first time release...
# 918   twitter may be about to end its threemonth sea...
# 1579  click to view fulltext httpswwwnbcnewscomtecht...
# 1938  there is good creepy and there is bad creepy a...
# 415   a new facebook dating service has been put on ...
#
#                                          tokenized_text  \
# 1502  [full, text, two, weeks, admitting, stored, hu...
# 808   [three, people, injured, gunfire, one, critica...
# 1262  [abstract, dan, gallagher, heard, street, arti...
# 1498  [google, 's, decisionmaking, process, youtube,...
# 111   [abstract, peers, rush, toward, public, offeri...
# 1250  [facebook, tuesday, first, time, released, rep...
# 918   [twitter, may, end, threemonth, search, new, c...
# 1579  [click, view, fulltext, httpswwwnbcnewscomtech...
# 1938  [good, creepy, bad, creepy, today, 's, creepy,...
# 415   [new, facebook, dating, service, put, hold, fo...
#
#                                     tokenized_text_join
# 1502  full text two weeks admitting stored hundreds ...
# 808   three people injured gunfire one critically sh...
# 1262  abstract dan gallagher heard street article wa...
# 1498  google 's decisionmaking process youtube video...
# 111   abstract peers rush toward public offerings so...
# 1250  facebook tuesday first time released report sh...
# 918   twitter may end threemonth search new ceo star...
# 1579  click view fulltext httpswwwnbcnewscomtechtech...
# 1938  good creepy bad creepy today 's creepy tomorro...
# 415   new facebook dating service put hold following...

# %%
ylabels =[]
xlabels = []
khali = []

# %%
ylabels = df['Relevant']

# %%
ylabels
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2218    0
# 2219    0
# 2220    0
# 2221    0
# 2222    0
# Name: Relevant, Length: 2223, dtype: int64

# %%
text_dfn
# Out:
#                                                    text  \
# 0     twitter's shares fell by more than 25pc in oct...
# 1     a company with no revenues and barely any staf...
# 2     youtube has been around forever in digital ter...
# 3     the new york offices of stockbrokers jp morgan...
# 4     facebook executives have been cautioning inves...
# ...                                                 ...
# 2218  many concepts have been proposed for meta lear...
# 2219  many online communities present usercontribute...
# 2220  logisticnormal topic models can effectively di...
# 2221  principal geodesic analysis pga is a generaliz...
# 2222  we formulate the problem of optimizing the sam...
#
#                                          tokenized_text  \
# 0     [twitter, 's, shares, fell, 25pc, october, hig...
# 1     [company, revenues, barely, staff, gets, acqui...
# 2     [youtube, around, forever, digital, terms, lea...
# 3     [new, york, offices, stockbrokers, jp, morgan,...
# 4     [facebook, executives, cautioning, investors, ...
# ...                                                 ...
# 2218  [many, concepts, proposed, meta, learning, neu...
# 2219  [many, online, communities, present, usercontr...
# 2220  [logisticnormal, topic, models, effectively, d...
# 2221  [principal, geodesic, analysis, pga, generaliz...
# 2222  [formulate, problem, optimizing, sampling, nat...
#
#                                     tokenized_text_join
# 0     twitter 's shares fell 25pc october highs 55 c...
# 1     company revenues barely staff gets acquired bi...
# 2     youtube around forever digital terms least for...
# 3     new york offices stockbrokers jp morgan flew f...
# 4     facebook executives cautioning investors socia...
# ...                                                 ...
# 2218  many concepts proposed meta learning neural ne...
# 2219  many online communities present usercontribute...
# 2220  logisticnormal topic models effectively discov...
# 2221  principal geodesic analysis pga generalization...
# 2222  formulate problem optimizing sampling natural ...
#
# [2223 rows x 3 columns]

# %%
for i in range(0,len(df)):
    if df['Relevant'][i] == 1:
        pass
    elif df['Relevant'][i] == 0:
        pass
    else:
        khali.append(i)

# %%
len(khali)
# Out:
# 0

# %%
khali
# Out:
# []

# %%
for i in khali:
    ylabels[i] = 0

# %%
ylabels
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2218    0
# 2219    0
# 2220    0
# 2221    0
# 2222    0
# Name: Relevant, Length: 2223, dtype: int64

# %%
ylabels.isnull().sum()
# Out:
# 0

# %%
text_dfn
# Out:
#                                                    text  \
# 0     twitter's shares fell by more than 25pc in oct...
# 1     a company with no revenues and barely any staf...
# 2     youtube has been around forever in digital ter...
# 3     the new york offices of stockbrokers jp morgan...
# 4     facebook executives have been cautioning inves...
# ...                                                 ...
# 2218  many concepts have been proposed for meta lear...
# 2219  many online communities present usercontribute...
# 2220  logisticnormal topic models can effectively di...
# 2221  principal geodesic analysis pga is a generaliz...
# 2222  we formulate the problem of optimizing the sam...
#
#                                          tokenized_text  \
# 0     [twitter, 's, shares, fell, 25pc, october, hig...
# 1     [company, revenues, barely, staff, gets, acqui...
# 2     [youtube, around, forever, digital, terms, lea...
# 3     [new, york, offices, stockbrokers, jp, morgan,...
# 4     [facebook, executives, cautioning, investors, ...
# ...                                                 ...
# 2218  [many, concepts, proposed, meta, learning, neu...
# 2219  [many, online, communities, present, usercontr...
# 2220  [logisticnormal, topic, models, effectively, d...
# 2221  [principal, geodesic, analysis, pga, generaliz...
# 2222  [formulate, problem, optimizing, sampling, nat...
#
#                                     tokenized_text_join
# 0     twitter 's shares fell 25pc october highs 55 c...
# 1     company revenues barely staff gets acquired bi...
# 2     youtube around forever digital terms least for...
# 3     new york offices stockbrokers jp morgan flew f...
# 4     facebook executives cautioning investors socia...
# ...                                                 ...
# 2218  many concepts proposed meta learning neural ne...
# 2219  many online communities present usercontribute...
# 2220  logisticnormal topic models effectively discov...
# 2221  principal geodesic analysis pga generalization...
# 2222  formulate problem optimizing sampling natural ...
#
# [2223 rows x 3 columns]

# %%
xlabels = text_dfn['tokenized_text_join'].copy()

# %%
xlabels
# Out:
# 0       twitter 's shares fell 25pc october highs 55 c...
# 1       company revenues barely staff gets acquired bi...
# 2       youtube around forever digital terms least for...
# 3       new york offices stockbrokers jp morgan flew f...
# 4       facebook executives cautioning investors socia...
#                               ...
# 2218    many concepts proposed meta learning neural ne...
# 2219    many online communities present usercontribute...
# 2220    logisticnormal topic models effectively discov...
# 2221    principal geodesic analysis pga generalization...
# 2222    formulate problem optimizing sampling natural ...
# Name: tokenized_text_join, Length: 2223, dtype: object

# %%
xlabels.isnull().sum()
# Out:
# 0

# %%
print(len(xlabels))
print(len(ylabels))
# Out:
# 2223
# 2223

# %%
print(xlabels.shape)
print(ylabels.shape)
# Out:
# (2223,)
# (2223,)

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(xlabels, ylabels, test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.15, random_state = 1)

# %%
vectorizer = CountVectorizer()

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
feature_names = vectorizer.get_feature_names_out()

# %%
vectorizer.vocabulary_
# Out:
# {'early': 11924,
#  'days': 10135,
#  'creating': 9474,
#  'social': 31525,
#  'network': 23285,
#  'mercy': 21777,
#  'internet': 18328,
#  'providers': 27092,
#  'could': 9275,
#  'easily': 11958,
#  'killed': 19425,
#  'company': 8439,
#  'first': 14089,
#  'glimpse': 15386,
#  'world': 37541,
#  'without': 37426,
#  'strong': 32679,
#  'protections': 27054,
#  'net': 23265,
#  'neutrality': 23311,
#  '2004': 948,
#  'part': 25056,
#  'team': 33603,
#  'created': 9472,
#  'facebook': 13376,
#  'though': 34119,
#  'itôs': 18686,
#  'hard': 16212,
#  'imagine': 17498,
#  'thefacebook': 33957,
#  'called': 6757,
#  'time': 34283,
#  'fledgling': 14206,
#  'college': 8242,
#  'growing': 15843,
#  'school': 29885,
#  'colleges': 8244,
#  'didnôt': 10867,
#  'like': 20326,
#  'functioned': 14850,
#  'studentsô': 32714,
#  'would': 37582,
#  'simply': 31044,
#  'block': 5722,
#  'site': 31119,
#  'blocks': 5736,
#  'always': 3426,
#  'rolled': 29161,
#  'back': 4756,
#  'often': 24097,
#  'sustained': 33162,
#  'student': 32710,
#  'outcry': 24542,
#  'acutely': 2720,
#  'demonstrated': 10517,
#  'power': 26364,
#  'limit': 20361,
#  'freedom': 14651,
#  'openness': 24308,
#  'whim': 37183,
#  'farfetched': 13638,
#  'suggest': 32902,
#  'schools': 29897,
#  'aggressive': 3063,
#  'unrelenting': 35825,
#  'blocking': 5734,
#  'might': 21977,
#  'exist': 13145,
#  'today': 34392,
#  'run': 29395,
#  'startup': 32269,
#  'philo': 25583,
#  'recently': 27894,
#  'introduced': 18403,
#  'streaming': 32605,
#  'live': 20481,
#  'tv': 35131,
#  'service': 30475,
#  'video': 36398,
#  'requires': 28552,
#  'bandwidth': 4912,
#  'reliable': 28303,
#  'connection': 8787,
#  'low': 20744,
#  'latencyù': 19849,
#  'long': 20614,
#  'takes': 33412,
#  'information': 17964,
#  'travel': 34784,
#  'system': 33325,
#  'services': 30483,
#  'particularly': 25074,
#  'prone': 26963,
#  'throttlingù': 34181,
#  'unfair': 35618,
#  'prioritization': 26722,
#  'tactics': 33367,
#  'longer': 20624,
#  'prohibited': 26905,
#  'chairman': 7329,
#  'federal': 13805,
#  'communications': 8417,
#  'commission': 8381,
#  'ajit': 3167,
#  'pai': 24845,
#  'announced': 3695,
#  'intent': 18262,
#  'even': 12953,
#  'worse': 37565,
#  'directly': 10982,
#  'competes': 8479,
#  'largest': 19813,
#  'offer': 24064,
#  'incentive': 17699,
#  'put': 27302,
#  'thumbs': 34198,
#  'scale': 29779,
#  'spurred': 32081,
#  'innovation': 18075,
#  'precisely': 26453,
#  'open': 24296,
#  'level': 20172,
#  'playing': 25947,
#  'field': 13923,
#  'barriers': 5010,
#  'offering': 24066,
#  'new': 23325,
#  'products': 26840,
#  'continually': 8989,
#  'come': 8315,
#  '1990s': 897,
#  'website': 36985,
#  'required': 28549,
#  'figuring': 13963,
#  'build': 6476,
#  'set': 30496,
#  'web': 36959,
#  'server': 30471,
#  'small': 31366,
#  'feat': 13789,
#  'started': 32257,
#  'rented': 28417,
#  '85': 2224,
#  'per': 25365,
#  'month': 22536,
#  'basic': 5040,
#  'hosting': 16998,
#  'cloud': 8041,
#  'free': 14648,
#  'year': 37760,
#  'meaning': 21561,
#  'anyone': 3862,
#  'idea': 17363,
#  'ability': 2453,
#  'get': 15238,
#  'however': 17056,
#  'allow': 3337,
#  'erect': 12754,
#  'reaching': 27746,
#  'customers': 9840,
#  'risk': 29024,
#  'reversing': 28820,
#  'trend': 34839,
#  'rules': 29375,
#  'donôt': 11516,
#  'protect': 27049,
#  'companies': 8432,
#  'also': 3391,
#  'consumer': 8925,
#  'ensure': 12611,
#  'youôre': 37934,
#  'getting': 15247,
#  'full': 14824,
#  'paying': 25206,
#  'provider': 27091,
#  'slows': 31350,
#  'want': 36784,
#  'look': 20655,
#  'denying': 10561,
#  'right': 28959,
#  'freely': 14663,
#  'choose': 7645,
#  'content': 8963,
#  'thatôs': 33939,
#  'important': 17616,
#  'see': 30170,
#  'clearly': 7945,
#  'crucial': 9661,
#  'understand': 35551,
#  'concerns': 8627,
#  'delivery': 10461,
#  'data': 10048,
#  'reaches': 27745,
#  'providerôs': 27093,
#  'whole': 37240,
#  'create': 9471,
#  'invisible': 18477,
#  'fast': 13685,
#  'laneù': 19788,
#  'someone': 31641,
#  'else': 12279,
#  'slowing': 31346,
#  'opponents': 24341,
#  'argue': 4115,
#  'throttling': 34180,
#  'actually': 2713,
#  'increase': 17760,
#  'certain': 7305,
#  'say': 29760,
#  'require': 28548,
#  'special': 31843,
#  'channel': 7384,
#  'shielded': 30710,
#  'congestion': 8749,
#  'fail': 13519,
#  'mention': 21752,
#  'already': 3386,
#  'possible': 26281,
#  'dedicated': 10304,
#  'links': 20414,
#  'guarantee': 15874,
#  'highly': 16662,
#  'commonplace': 8404,
#  'within': 37424,
#  'framework': 14588,
#  'neutral': 23308,
#  'fact': 13472,
#  'uninterrupted': 35694,
#  'television': 33726,
#  'feeds': 13820,
#  'servers': 30472,
#  'truth': 35007,
#  'arguments': 4120,
#  'cover': 9372,
#  'opposed': 24346,
#  'really': 27804,
#  'extract': 13304,
#  'payments': 25210,
#  'consumers': 8928,
#  'equal': 12718,
#  'access': 2562,
#  'course': 9346,
#  'claim': 7824,
#  'support': 33047,
#  'principles': 26706,
#  'voluntarily': 36633,
#  'follow': 14340,
#  'regulations': 28195,
#  'unfortunately': 35643,
#  'count': 9289,
#  'proven': 27084,
#  'untrustworthy': 35898,
#  'comcast': 8314,
#  'deleted': 10426,
#  'pledge': 25974,
#  'paid': 24846,
#  'day': 10129,
#  'mr': 22735,
#  'proposal': 27003,
#  'repeal': 28445,
#  'current': 9800,
#  'news': 23352,
#  'ars': 4198,
#  'technica': 33639,
#  'uncovered': 35484,
#  'seems': 30186,
#  'assured': 4387,
#  'despite': 10703,
#  'threequarters': 34155,
#  'americans': 3495,
#  'supporting': 33052,
#  'many': 21173,
#  'commissioners': 8384,
#  'fcc': 13769,
#  'vote': 36647,
#  'thursday': 34210,
#  'seem': 30182,
#  'listening': 20452,
#  'verizon': 36314,
#  'att': 4456,
#  'large': 19809,
#  'shouldnôt': 30826,
#  'stop': 32520,
#  'fighting': 13953,
#  'make': 21036,
#  'voices': 36612,
#  'heard': 16436,
#  'paiôs': 24869,
#  'adopted': 2840,
#  'must': 22919,
#  'take': 33402,
#  'fight': 13949,
#  'congress': 8763,
#  'courts': 9363,
#  'regain': 28146,
#  'ensures': 12613,
#  'choice': 7636,
#  'constraint': 8902,
#  'never': 23317,
#  'concede': 8605,
#  'importance': 17614,
#  'great': 15709,
#  'york': 37837,
#  'times': 34301,
#  'opinion': 24333,
#  'section': 30142,
#  'twitter': 35197,
#  'nytopinion': 23884,
#  'sign': 30947,
#  'newsletter': 23367,
#  'andrew': 3608,
#  'mccollum': 21501,
#  'chief': 7576,
#  'executive': 13107,
#  'penelitian': 25319,
#  'ini': 18029,
#  'bertujuan': 5397,
#  'menganalisis': 21737,
#  'pengaruh': 25323,
#  'pembelajaran': 25298,
#  'berbasis': 5368,
#  'proyek': 27119,
#  'dengan': 10531,
#  'presentasi': 26567,
#  'youtube': 37892,
#  'sebagai': 30106,
#  'tugas': 35059,
#  'akhir': 3173,
#  'terhadap': 33808,
#  'hasil': 16305,
#  'belajar': 5271,
#  'online': 24250,
#  'ranah': 27611,
#  'kognitif': 19572,
#  'untuk': 35901,
#  'mata': 21382,
#  'kuliah': 19652,
#  'bahasa': 4833,
#  'inggris': 18004,
#  'fisika': 14116,
#  'menggunakan': 21738,
#  'pendekatan': 25314,
#  'kuantitatif': 19644,
#  'metode': 21853,
#  'kuasi': 19645,
#  'eksperimen': 12171,
#  'desain': 10646,
#  'adalah': 2725,
#  'posttest': 26320,
#  'nonequivalent': 23581,
#  'design': 10669,
#  'populasi': 26204,
#  'dalam': 9943,
#  'mahasiswa': 20989,
#  'tadris': 33370,
#  'semester': 30336,
#  'iv': 18688,
#  'yang': 37732,
#  'berjumlah': 5377,
#  '32': 1397,
#  'oarang': 23893,
#  'penarikan': 25308,
#  'sampel': 29613,
#  'teknik': 33692,
#  'sampling': 29617,
#  'jenuh': 18879,
#  'instrumen': 18202,
#  'digunakan': 10920,
#  '20': 937,
#  'soal': 31511,
#  'pilihan': 25764,
#  'ganda': 15000,
#  'peneliti': 25318,
#  'uji': 35345,
#  'dan': 9972,
#  'korelasi': 19592,
#  'phi': 25567,
#  'taraf': 33501,
#  'signifikansi': 30972,
#  '005': 34,
#  'menunjukkan': 21760,
#  'bahwa': 4838,
#  'terdapat': 33806,
#  'perbedaan': 25366,
#  'prestasi': 26614,
#  'dimana': 10932,
#  'kelas': 19307,
#  'lebih': 20027,
#  'baik': 4841,
#  'dari': 10013,
#  'kontrol': 19583,
#  'kemudian': 19321,
#  'kerja': 19344,
#  'berpengaruh': 5394,
#  'signifikan': 30971,
#  'pada': 24821,
#  'succumbing': 32873,
#  'public': 27160,
#  'pressure': 26609,
#  'released': 28289,
#  'gender': 15140,
#  'ethnic': 12875,
#  'breakdown': 6191,
#  'workforce': 37521,
#  'wednesday': 37003,
#  'showing': 30852,
#  'looks': 20663,
#  'major': 21027,
#  'technology': 33655,
#  'overwhelmingly': 24763,
#  'male': 21055,
#  'white': 37209,
#  'asian': 4277,
#  'yous': 37870,
#  'nearly': 23149,
#  '90': 2279,
#  'workers': 37519,
#  'jobs': 18973,
#  'held': 16506,
#  'whites': 37226,
#  'asians': 4280,
#  'men': 21730,
#  '70': 2040,
#  'staff': 32158,
#  'according': 2595,
#  'figures': 13960,
#  'vice': 36371,
#  'president': 26588,
#  'diversity': 11346,
#  'inclusion': 17726,
#  'janet': 18782,
#  'van': 36174,
#  'huysse': 17276,
#  'blog': 5744,
#  'post': 26285,
#  'said': 29536,
#  'knows': 19563,
#  'lot': 20704,
#  'work': 37512,
#  'makes': 21042,
#  'good': 15505,
#  'business': 6607,
#  'sense': 30378,
#  'employees': 12411,
#  'representative': 28500,
#  'vast': 36216,
#  'varied': 36205,
#  'backgrounds': 4773,
#  'users': 36064,
#  'around': 4165,
#  'proud': 27079,
#  'issue': 18639,
#  'become': 5188,
#  'hotly': 17013,
#  'debated': 10195,
#  'silicon': 30998,
#  'valley': 36158,
#  'powerful': 26368,
#  'begun': 5231,
#  'revealing': 28796,
#  'makeup': 21044,
#  'workforces': 37523,
#  'diversifying': 11344,
#  'ranks': 27644,
#  'stay': 32328,
#  'touch': 34561,
#  'tune': 35074,
#  'past': 25124,
#  'two': 35264,
#  'months': 22539,
#  'yahoo': 37724,
#  'google': 15527,
#  'linkedin': 20410,
#  'reported': 28481,
#  'staffs': 32165,
#  '62': 1951,
#  '88': 2250,
#  '91': 2296,
#  'dismayed': 11177,
#  'blacks': 5635,
#  'hispanics': 16756,
#  'yet': 37811,
#  'tiny': 34333,
#  'percentage': 25370,
#  'reaping': 27819,
#  'economic': 12006,
#  'rewards': 28866,
#  'nation': 23068,
#  'toppaying': 34497,
#  'industry': 17860,
#  'hispanic': 16755,
#  'black': 5615,
#  'account': 2599,
#  '41': 1598,
#  'making': 21046,
#  'racially': 27501,
#  'diverse': 11340,
#  'numbers': 23836,
#  'pathetic': 25149,
#  'step': 32383,
#  'direction': 10976,
#  'rev': 28789,
#  'jesse': 18905,
#  'jackson': 18729,
#  'interview': 18371,
#  'rainbow': 27563,
#  'push': 27296,
#  'coalition': 8101,
#  'civil': 7811,
#  'rights': 28966,
#  'organization': 24440,
#  'colorofchangeorg': 8280,
#  'last': 19831,
#  'week': 37010,
#  'began': 5216,
#  'campaigning': 6813,
#  'share': 30614,
#  'demographic': 10503,
#  'begin': 5223,
#  'setting': 30501,
#  'targets': 33512,
#  'timetable': 34314,
#  'tech': 33625,
#  '37': 1518,
#  'female': 13851,
#  '30': 1332,
#  '31': 1370,
#  '39': 1554,
#  'source': 31736,
#  'usa': 36030,
#  'research': 28562,
#  'inevitable': 17881,
#  'messaging': 21809,
#  'start': 32256,
#  'attracting': 4508,
#  'mainstream': 21014,
#  'coverage': 9373,
#  'celebrities': 7229,
#  'piled': 25760,
#  'stephen': 32389,
#  'fry': 14782,
#  'credit': 9498,
#  'possibly': 26283,
#  'blame': 5648,
#  'stuck': 32708,
#  'lift': 20305,
#  'jonathan': 19020,
#  'ross': 29239,
#  'chatshow': 7468,
#  'guests': 15900,
#  'phenomenon': 25564,
#  'quickly': 27427,
#  'mustdo': 22924,
#  'community': 8424,
#  'since': 31063,
#  'launched': 19882,
#  'july': 19127,
#  '2006': 950,
#  'twitterers': 35227,
#  'pew': 25532,
#  'american': 3487,
#  'life': 20283,
#  'project': 26914,
#  'shows': 30857,
#  '76': 2120,
#  'use': 36043,
#  'mobile': 22339,
#  'compared': 8453,
#  '59': 1876,
#  'rest': 28662,
#  'us': 36027,
#  'population': 26208,
#  'active': 2695,
#  'media': 21590,
#  'generally': 15150,
#  '27': 1235,
#  'likely': 20332,
#  'twice': 35184,
#  'national': 23069,
#  'average': 4646,
#  'although': 3410,
#  'popular': 26200,
#  '1824s': 784,
#  '19': 826,
#  'aged': 3025,
#  '25': 1184,
#  '34': 1447,
#  'median': 21606,
#  'age': 3024,
#  'older': 24130,
#  '26': 1217,
#  'myspace': 22957,
#  'reveal': 28794,
#  'user': 36050,
#  'recent': 27893,
#  'welleducated': 37067,
#  'guesses': 15894,
#  'regular': 28186,
#  'monthly': 22538,
#  'audience': 4529,
#  'million': 22038,
#  'globally': 15397,
#  'results': 28703,
#  'show': 30840,
#  'less': 20139,
#  'read': 27760,
#  'printed': 26711,
#  'newspaper': 23373,
#  '60': 1905,
#  'nontwitterers': 23648,
#  '14': 567,
#  'surprised': 33101,
#  'used': 36044,
#  'discuss': 11126,
#  'cases': 7050,
#  'report': 28479,
#  'breaking': 6196,
#  'says': 29768,
#  'om': 24163,
#  'malik': 21068,
#  'veteran': 36344,
#  'reporter': 28483,
#  'gigaom': 15294,
#  'one': 24209,
#  'people': 25345,
#  'communicate': 8411,
#  'megaphone': 21661,
#  'planet': 25889,
#  'send': 30365,
#  'messages': 21806,
#  'phoned': 25599,
#  'friends': 14715,
#  'instead': 18174,
#  'may': 21466,
#  'consider': 8841,
#  'publishing': 27193,
#  'tool': 34468,
#  'still': 32442,
#  'essentially': 12831,
#  'communication': 8415,
#  'platform': 25913,
#  'provides': 27094,
#  'constructive': 8908,
#  'twoway': 35286,
#  'medium': 21633,
#  'allows': 3343,
#  'individuals': 17841,
#  'ideas': 17371,
#  'connections': 8788,
#  'infinite': 17924,
#  'amount': 3521,
#  'journalist': 19057,
#  'hold': 16827,
#  'hand': 16112,
#  'this': 34099,
#  'need': 23173,
#  'conservative': 8831,
#  'personality': 25464,
#  'milo': 22052,
#  'yiannopoulos': 37816,
#  'permanently': 25419,
#  'banned': 4939,
#  'pointed': 26057,
#  'policing': 26107,
#  'vulgarity': 36688,
#  'violent': 36499,
#  'islamic': 18606,
#  'state': 32277,
#  'lives': 20490,
#  'matter': 21418,
#  'vigor': 36455,
#  'tuesday': 35050,
#  'night': 23456,
#  'gay': 15088,
#  'british': 6319,
#  'activist': 2699,
#  'editor': 12053,
#  'breitbart': 6223,
#  'expressed': 13268,
#  'abusive': 2533,
#  'comments': 8370,
#  'toward': 34595,
#  'leslie': 20137,
#  'jones': 19021,
#  'actress': 2709,
#  'role': 29154,
#  'ghostbusters': 15266,
#  'movie': 22715,
#  'able': 2458,
#  'express': 13267,
#  'opinions': 24336,
#  'beliefs': 5286,
#  'statement': 32288,
#  'deserves': 10667,
#  'subjected': 32772,
#  'targeted': 33507,
#  'abuse': 2525,
#  'prohibit': 26904,
#  'inciting': 17719,
#  'engaging': 12543,
#  'harassment': 16203,
#  'others': 24506,
#  'forms': 14482,
#  'remain': 28333,
#  'besides': 5400,
#  'isis': 18601,
#  'every': 12981,
#  'islamist': 18607,
#  'group': 15824,
#  'planning': 25894,
#  'organizing': 24451,
#  'highestranking': 16651,
#  'member': 21701,
#  'shaun': 30649,
#  'king': 19453,
#  'calling': 6761,
#  'coup': 9333,
#  'trump': 34974,
#  'elected': 12188,
#  'fox': 14564,
#  'another': 3723,
#  'example': 13045,
#  'gavin': 15084,
#  'three': 34143,
#  'police': 26097,
#  'officers': 24076,
#  'baton': 5072,
#  'rouge': 29262,
#  '17': 721,
#  'wounded': 37590,
#  'convoswithcosmo': 9096,
#  'remained': 28335,
#  'incident': 17709,
#  'filled': 13980,
#  'intended': 18250,
#  'inspirational': 18141,
#  'related': 28267,
#  'wake': 36731,
#  'morning': 22594,
#  'mean': 21560,
#  'living': 20501,
#  'physical': 25649,
#  'body': 5850,
#  'dead': 10161,
#  'final': 14001,
#  'message': 21804,
#  'dated': 10087,
#  'attack': 4463,
#  'supporters': 33050,
#  'thank': 33923,
#  'brother': 6379,
#  'peace': 25241,
#  'response': 28653,
#  'old': 24129,
#  'kanye': 19222,
#  'violence': 36495,
#  'answer': 3728,
#  'point': 26055,
#  'stand': 32217,
#  'native': 23086,
#  'americansextinct': 3496,
#  '13': 500,
#  'adherents': 2775,
#  'similarly': 31022,
#  'claims': 7829,
#  'deactivated': 10158,
#  '125000': 454,
#  'accounts': 2608,
#  'affiliated': 2954,
#  'mid2015': 21931,
#  'operators': 24330,
#  'associated': 4368,
#  'hacking': 16004,
#  'anonymous': 3721,
#  'taken': 33407,
#  '120000': 419,
#  'hackers': 16003,
#  'tweeted': 35153,
#  '13000': 502,
#  'several': 30525,
#  'action': 2686,
#  'casual': 7092,
#  'well': 37058,
#  'saltwater': 29590,
#  'patricia': 25164,
#  'includes': 17724,
#  'tweet': 35149,
#  'pundit': 27234,
#  'bill': 5516,
#  'maher': 20990,
#  'curses': 9813,
#  'describing': 10656,
#  'republican': 28525,
#  'presidential': 26591,
#  'candidate': 6850,
#  'donald': 11494,
#  'sons': 31674,
#  'looking': 20660,
#  'date': 10084,
#  'rapists': 27669,
#  'subject': 32771,
#  'racial': 27500,
#  'terminology': 33820,
#  'questioned': 27411,
#  'lord': 20686,
#  'february': 13803,
#  'concluding': 8642,
#  'profanity': 26847,
#  'refer': 28081,
#  'uncle': 35461,
#  'tom': 34435,
#  'cnbc': 8081,
#  'accused': 2633,
#  'systematic': 33326,
#  'discrimination': 11120,
#  'lying': 20866,
#  'campaign': 6806,
#  'libertarian': 20250,
#  'points': 26065,
#  'view': 36434,
#  'apply': 3974,
#  'capriciously': 6910,
#  'inconsistently': 17746,
#  'explanation': 13226,
#  'added': 2744,
#  'perfectly': 25389,
#  'happy': 16196,
#  'host': 16989,
#  'death': 10185,
#  'threats': 34142,
#  'joke': 19006,
#  'feminist': 13855,
#  'dislike': 11168,
#  'audacity': 4526,
#  'hollywood': 16850,
#  'happens': 16190,
#  'woman': 37465,
#  'suspended': 33144,
#  'absurd': 2521,
#  'blocked': 5732,
#  'huawei': 17164,
#  'applications': 3971,
#  'preinstalled': 26510,
#  'smartphones': 31378,
#  'latest': 19855,
#  'development': 10776,
#  'ongoing': 24248,
#  'trade': 34640,
#  'war': 36789,
#  'china': 7607,
#  'sister': 31114,
#  'brands': 6149,
#  'whatsapp': 37160,
#  'instagram': 18148,
#  'available': 4635,
#  'default': 10341,
#  'phones': 25602,
#  'giant': 15273,
#  'works': 37535,
#  'comply': 8541,
#  'government': 15584,
#  'blacklisting': 5627,
#  'leader': 19966,
#  'developing': 10775,
#  '5g': 1893,
#  'networks': 23291,
#  'blacklisted': 5626,
#  'following': 14351,
#  'repeated': 28448,
#  'accusations': 2630,
#  'espionage': 12815,
#  'reviewing': 28827,
#  'commerce': 8372,
#  'department': 10568,
#  'rule': 29369,
#  'issued': 18641,
#  'temporary': 33759,
#  'general': 15145,
#  'licence': 20264,
#  'taking': 33415,
#  'steps': 32395,
#  'compliance': 8524,
#  'spokesperson': 31998,
#  'suspension': 33150,
#  'affect': 2943,
#  'smartphone': 31377,
#  'owners': 24779,
#  'forced': 14412,
#  'download': 11614,
#  'independently': 17796,
#  'play': 25935,
#  'store': 32532,
#  'buy': 6646,
#  'handsets': 16145,
#  'ban': 4897,
#  'comes': 8323,
#  'effect': 12088,
#  'among': 3514,
#  'lobbying': 20531,
#  'administration': 2801,
#  'exempt': 13114,
#  'exports': 13257,
#  'avoid': 4666,
#  'shutdown': 30887,
#  'focus': 14318,
#  'protecting': 27051,
#  'security': 30158,
#  'millions': 22044,
#  'existing': 13152,
#  'executives': 13108,
#  'argued': 4116,
#  'compromise': 8572,
#  'financial': 14012,
#  'requirements': 28551,
#  'storm': 32544,
#  'michael': 21882,
#  'wessel': 37117,
#  'commissioner': 8383,
#  'uschina': 36041,
#  'review': 28822,
#  'assessment': 4345,
#  'shortsighted': 30812,
#  'represents': 28504,
#  'commercial': 8373,
#  'interests': 18298,
#  'activity': 2703,
#  'respond': 28645,
#  'inadequate': 17673,
#  'late': 19842,
#  'coming': 8337,
#  'broad': 6335,
#  'deep': 10317,
#  'supply': 33045,
#  'chains': 7326,
#  'relationships': 28275,
#  'carefully': 6969,
#  'assess': 4341,
#  'risks': 29026,
#  'advance': 2873,
#  'areas': 4100,
#  'far': 13625,
#  'android': 3611,
#  'operating': 24321,
#  'maps': 21182,
#  'update': 35935,
#  'systems': 33330,
#  'tried': 34885,
#  'speed': 31896,
#  'reversal': 28815,
#  'launching': 19886,
#  'legal': 20053,
#  'arguing': 4118,
#  'law': 19909,
#  'bans': 4951,
#  'purchases': 27265,
#  'chinese': 7612,
#  'telecoms': 33699,
#  'firm': 14083,
#  'unconstitutional': 35474,
#  'experts': 13214,
#  'find': 14016,
#  'dominance': 11477,
#  'market': 21243,
#  'contested': 8975,
#  'creates': 9473,
#  'rival': 29039,
#  'emily': 12363,
#  'taylor': 33580,
#  'associate': 4367,
#  'fellow': 13843,
#  'thinktank': 34076,
#  'chatham': 7465,
#  'house': 17031,
#  'scratching': 29995,
#  'heads': 16407,
#  'years': 37778,
#  'break': 6190,
#  'position': 26263,
#  'stumbled': 32728,
#  'solution': 31620,
#  'provide': 27088,
#  'opportunity': 24344,
#  'competitor': 8490,
#  'enter': 12620,
#  'mass': 21344,
#  'prominent': 26938,
#  'neonazi': 23242,
#  'addition': 2752,
#  'removing': 28387,
#  'whitesupremacist': 37229,
#  'pages': 24837,
#  'saturday': 29721,
#  'deadly': 10166,
#  'virginia': 36512,
#  'protest': 27060,
#  'removed': 28384,
#  'selfdescribed': 30243,
#  'fascist': 13677,
#  'christopher': 7692,
#  'cantwell': 6874,
#  ...}

# %%
print("LogisticRegression")
print("__________________")
print("                  ")

logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(logreg.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(logreg.score(X_test,y_test)))

pred_logreg = logreg.predict(X_test)
confusion = confusion_matrix(y_test, pred_logreg)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# LogisticRegression
# __________________
#
# Train set accuracy: 0.998
# Test set accuracy: 0.822
# Confusion Matrix:
# [[100  46]
#  [ 33 266]]

# %%
scores = cross_val_score(LogisticRegression(solver='lbfgs', max_iter=1000),X_train,y_train,cv=5)
print("Mean cross-Validation accuracy: {:.2f}".format(np.mean(scores)))

param_grid = {"C":[0.001, 0.01, 0.1, 1, 10, 100]}

grid = GridSearchCV(LogisticRegression(solver='lbfgs', max_iter=1000), param_grid, cv=5)
grid.fit(X_train, y_train)
print("Best Cross-validation score: {:.2f}".format(grid.best_score_))
print("Best parameters: ", grid.best_params_)
# Out:
# Mean cross-Validation accuracy: 0.83
# Best Cross-validation score: 0.83
# Best parameters:  {'C': 1}

# %%
print("Multinomial Naive Bayes")
print("__________________")
print("                  ")

nb = MultinomialNB()
nb.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(nb.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(nb.score(X_test,y_test)))

pred_nb = nb.predict(X_test)
confusion = confusion_matrix(y_test, pred_nb)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# Multinomial Naive Bayes
# __________________
#
# Train set accuracy: 0.962
# Test set accuracy: 0.838
# Confusion Matrix:
# [[ 94  52]
#  [ 20 279]]

# %%
print("Naive Bayes")
print("__________________")
print("                  ")

nv = naive_bayes.MultinomialNB()
nv.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(nv.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(nv.score(X_test,y_test)))

pred_nv = nv.predict(X_test)
confusion = confusion_matrix(y_test, pred_nv)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# Naive Bayes
# __________________
#
# Train set accuracy: 0.962
# Test set accuracy: 0.838
# Confusion Matrix:
# [[ 94  52]
#  [ 20 279]]

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
print("SVM")
print("__________________")
print("                  ")

SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train,y_train)# predict the labels on validation dataset
predictions_SVM = SVM.predict(X_test)# Use accuracy_score function to get the accuracy


print("Test set accuracy: ", accuracy_score(predictions_SVM, y_test))

confusion = confusion_matrix(y_test, predictions_SVM)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# SVM
# __________________
#
# Test set accuracy:  0.8179775280898877
# Confusion Matrix:
# [[103  43]
#  [ 38 261]]

# %%
print("Random Forest")
print("__________________")
print("                  ")

rf = RandomForestClassifier()
rf.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(rf.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(rf.score(X_test,y_test)))

pred_rf = rf.predict(X_test)
confusion = confusion_matrix(y_test, pred_rf)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# Random Forest
# __________________
#
# Train set accuracy: 0.999
# Test set accuracy: 0.791
# Confusion Matrix:
# [[ 62  84]
#  [  9 290]]

# %%
print("Decision Tree")
print("__________________")
print("                  ")


tree = DecisionTreeClassifier()
tree.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(tree.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(tree.score(X_test,y_test)))

pred_tree = tree.predict(X_test)
confusion = confusion_matrix(y_test, pred_tree)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# Decision Tree
# __________________
#
# Train set accuracy: 0.999
# Test set accuracy: 0.728
# Confusion Matrix:
# [[ 94  52]
#  [ 69 230]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, metrics
from sklearn.linear_model import LinearRegression
print("Linear Regression")
print("__________________")
print("                  ")


reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(reg.score(X_train,y_train)))

pred_reg = reg.predict(X_test)
print("Test set accuracy: {:.3f}".format(reg.score(X_test,pred_reg)))
# Out:
# Linear Regression
# __________________
#
# Train set accuracy: 0.997
# Test set accuracy: 1.000

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

print("K-means")
print("__________________")
print("                  ")

kmn = KMeans(init="random",n_clusters=2,n_init=10,max_iter=300,random_state=42)
kmn.fit(X_train,y_train)
print("Train set accuracy: {:.3f}".format(kmn.score(X_train,y_train)))
print("Test set accuracy: {:.3f}".format(kmn.score(X_test,y_test)))

pred_kmn = kmn.predict(X_test)
confusion = confusion_matrix(y_test, pred_kmn)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# K-means
# __________________
#
# Train set accuracy: -1301721.108
# Test set accuracy: -357422.588
# Confusion Matrix:
# [[  6 140]
#  [ 85 214]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

print("KNN")
print("__________________")
print("                  ")


sc = StandardScaler(with_mean=False)
X_trainknn = sc.fit_transform(X_train)
X_testknn = sc.transform(X_test)


knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn.fit(X_trainknn,y_train)
print("Train set accuracy: {:.3f}".format(knn.score(X_trainknn,y_train)))
print("Test set accuracy: {:.3f}".format(knn.score(X_testknn,y_test)))

pred_knn = knn.predict(X_testknn)
confusion = confusion_matrix(y_test, pred_knn)
print("Confusion Matrix:\n{}".format(confusion))
# Out:
# KNN
# __________________
#
# Train set accuracy: 0.696
# Test set accuracy: 0.676
# Confusion Matrix:
# [[  2 144]
#  [  0 299]]
